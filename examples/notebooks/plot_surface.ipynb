# %% [markdown]
# # Postprocessing variables from visdump hdf5 file.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
import numpy as np

import sys
sys.path.append("/Users/shua784/github/modvis")
import modvis.ATSutils as utils 
import modvis.ats_xdmf as xdmf
import modvis.transect_data as transect_data
import modvis.plot_vis_file as pv
import modvis.general_plots as gp
import modvis.utils as ut 
import modvis.colors as mcolors
import modvis.objectivefunctions as ofs

# %%
model_dir = "../data/coalcreek/"

prefix = "ats_vis"
surface_mesh = f"{prefix}_surface_mesh.h5"
surface_h5 = f"{prefix}_surface_data.h5"

# %% [markdown]
# # import vis data

# %%
visfile = xdmf.VisFile(model_dir, domain='surface', filename=surface_h5, 
                       mesh_filename=surface_mesh, load_mesh=True,
                      )

# %% [markdown]
# # plot surface ponded depth

# %%
fig, ax, tpc = pv.plot_surface_data(visfile, var_name="surface-ponded_depth", 
                                    log = True, vmin=0.01, vmax=4, 
                                    time_slice=0)
# Out:
# 2022-05-17 21:46:57,240 - root - INFO: No unit convertion.

# %% [markdown]
# # plot ET

# %%
fig, ax, tpc = pv.plot_surface_data(visfile, var_name="surface-total_evapotranspiration", 
                                    log = False, vmin=0, vmax=3, 
                                    time_slice= "2015-10-01")

# %% [markdown]
# # plot snow cover

# %%
fig, ax, tpc = pv.plot_surface_data(visfile, var_name="surface-area_fractions.cell.1", 
                                    vmin=0, vmax=1, time_slice=0)
# Out:
# 2022-05-17 21:46:58,216 - root - INFO: No unit convertion.
